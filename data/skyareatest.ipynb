# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.stats import binned_statistic
import sys; sys.path.insert(0, '/srv/one/zhutchen/paper3/codes/')
from survey_volume import solid_angle, integrate_volume, comoving_volume, comoving_volume_shell
import pickle

from astropy.cosmology import LambdaCDM
cosmo = LambdaCDM(70.,0.3,0.7)

# %% [markdown]
# # test ECO

# %%
eco = pd.read_csv("/srv/one/zhutchen/g3groupfinder/resolve_and_eco/ECOdata_G3catalog_luminosity.csv")

# %%
plt.figure()
plt.plot(eco.radeg, eco.dedeg,'k.')
plt.show()

# %%
solid_angle(eco.radeg, eco.dedeg, bins=100)
# Out:
# 4510.410207428554

# %% [markdown]
# # test laduma

# %%
sv = pd.read_hdf('./subvolumes/subvolume_0.5_to_0.7.hdf5')

# %%
plt.figure()
plt.plot(sv.RAall, sv.DECall,'k.')
plt.show()

# %%
solid_angle(sv.RAall, sv.DECall, bins=500)
# Out:
# 3.9065101175126173

# %%
# what would you get if it was a lat long rectangle?
# 4.4 deg according to https://rdrr.io/cran/celestial/man/skyarea.html
sv.RAall.min(), sv.RAall.max(), sv.DECall.min(), sv.DECall.max()
# Out:
# (51.68266677856445, 54.00131607055664, -29.13342, -26.980897903442383)

# %%
3.9 / 4.4
# Out:
# 0.8863636363636362

# %%
# about a 10% difference where my solid_angle is smaller --- this makes sense.
